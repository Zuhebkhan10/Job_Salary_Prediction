# %%
import pandas as pd

df=pd.read_csv('Dataset/job_salary.csv')

df.head()
# Out:
#             job_title  experience_years education_level  skills_count  \
# 0         AI Engineer                10        Bachelor             2
# 1        Data Analyst                 5        Bachelor            17
# 2  Frontend Developer                18             PhD             4
# 3    Business Analyst                19             PhD            13
# 4     Product Manager                15        Bachelor             7
#
#         industry company_size   location remote_work  certifications  salary
# 0     Healthcare       Medium      India      Hybrid               2  109413
# 1        Telecom        Small  Australia          No               0   93764
# 2          Media       Medium  Singapore          No               1  148123
# 3         Retail       Medium     Canada         Yes               0  189123
# 4  Manufacturing        Large     Sweden         Yes               0  165069

# %%
# . Selecting Specific Columns
# How would you select just the job_title and Salary columns?

res=df[['job_title','salary']]
res.head()
# Out:
#             job_title  salary
# 0         AI Engineer  109413
# 1        Data Analyst   93764
# 2  Frontend Developer  148123
# 3    Business Analyst  189123
# 4     Product Manager  165069

# %%
# Filtering Rows:
# Can you show me all employees earning more than 90,000

res=df[df['salary']>90000]
res.head()

# Explanation: You create a boolean mask by writing a condition, then use it to filter the DataFrame.
# This is called boolean indexing.
# Out:
#             job_title  experience_years education_level  skills_count  \
# 0         AI Engineer                10        Bachelor             2
# 1        Data Analyst                 5        Bachelor            17
# 2  Frontend Developer                18             PhD             4
# 3    Business Analyst                19             PhD            13
# 4     Product Manager                15        Bachelor             7
#
#         industry company_size   location remote_work  certifications  salary
# 0     Healthcare       Medium      India      Hybrid               2  109413
# 1        Telecom        Small  Australia          No               0   93764
# 2          Media       Medium  Singapore          No               1  148123
# 3         Retail       Medium     Canada         Yes               0  189123
# 4  Manufacturing        Large     Sweden         Yes               0  165069

# %%
# Adding a New Column
# How would you add a Bonus column that's 20% of the Salary?

df['Bonus']=df['salary']*0.20
df.tail()

# Explanation: You can create new columns by simply assigning values to a new column name.
# The calculation is applied element-wise.
# Out:
#                  job_title  experience_years education_level  skills_count  \
# 249995   Software Engineer                17             PhD             2
# 249996  Frontend Developer                20             PhD             7
# 249997    Business Analyst                 1        Bachelor            12
# 249998      Data Scientist                 0     High School             2
# 249999        Data Analyst                16         Diploma             2
#
#           industry company_size location remote_work  certifications  salary  \
# 249995     Telecom   Enterprise    India          No               1  127791
# 249996     Telecom      Startup   Remote          No               2  154593
# 249997      Retail   Enterprise    India         Yes               0   75988
# 249998  Consulting        Small   Sweden      Hybrid               5   90467
# 249999  Technology       Medium       UK          No               5  133084
#
#           Bonus
# 249995  25558.2
# 249996  30918.6
# 249997  15197.6
# 249998  18093.4
# 249999  26616.8

# %%
# Sorting Data
# Could you sort the employees by salary from highest to lowest?

sorted_data=df.sort_values('salary',ascending='False')
sorted_data
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[17], line 4
#       1 # Sorting Data
#       2 # Could you sort the employees by salary from highest to lowest?
# ----> 4 sorted_data=df.sort_values('salary',ascending='False')
#       5 sorted_data
#
# File ~\anaconda3\Lib\site-packages\pandas\core\frame.py:7179, in DataFrame.sort_values(self, by, axis, ascending, inplace, kind, na_position, ignore_index, key)
#    7177 inplace = validate_bool_kwarg(inplace, "inplace")
#    7178 axis = self._get_axis_number(axis)
# -> 7179 ascending = validate_ascending(ascending)
#    7180 if not isinstance(by, list):
#    7181     by = [by]
#
# File ~\anaconda3\Lib\site-packages\pandas\util\_validators.py:362, in validate_ascending(ascending)
#     359 if not isinstance(ascending, Sequence):
#     360     return validate_bool_kwarg(ascending, "ascending", **kwargs)
# --> 362 return [validate_bool_kwarg(item, "ascending", **kwargs) for item in ascending]
#
# File ~\anaconda3\Lib\site-packages\pandas\util\_validators.py:264, in validate_bool_kwarg(value, arg_name, none_allowed, int_allowed)
#     261     good_value = good_value or isinstance(value, int)
#     263 if not good_value:
# --> 264     raise ValueError(
#     265         f'For argument "{arg_name}" expected type bool, received '
#     266         f"type {type(value).__name__}."
#     267     )
#     268 return value
#
# ValueError: For argument "ascending" expected type bool, received type str.
